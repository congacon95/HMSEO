# %%
from requests import get
import json

# %%
import sys
if 'E:\\jupyter_notebook\\HomemadeSEO_Phil\\' not in sys.path:
    sys.path.append('E:\\jupyter_notebook\\HomemadeSEO_Phil\\')
from ptl.get import save
#get.setup(debug=True, driver=False)

# %%
api_url='https://www.googleapis.com/pagespeedonline/v1/runPagespeed'
target_url='http://www.lazada.vn/'
key='AIzaSyDGwAgFUs25FrsK6Rg_C7ketQ3K5jyo9og'
target_device='desktop'
desktop=get.get(api_url+'?url='+target_url+'&key='+key+'&strategy=desktop')
mobile=get.get(api_url+'?url='+target_url+'&key='+key+'&strategy=mobile')

# %%
print(desktop.content.decode('utf8'))
# Out:
# {
#  "kind": "pagespeedonline#result",
#  "id": "http://www.lazada.vn/cach-mang-mua-sam-online/",
#  "responseCode": 200,
#  "title": "Chương trình khuyến mãi Cách Mạng Mua Sắm Online tại Lazada.vn",
#  "score": 61,
#  "pageStats": {
#   "numberResources": 124,
#   "numberHosts": 46,
#   "totalRequestBytes": "25984",
#   "numberStaticResources": 68,
#   "htmlResponseBytes": "3435095",
#   "textResponseBytes": "1302",
#   "cssResponseBytes": "1236162",
#   "imageResponseBytes": "793590",
#   "javascriptResponseBytes": "2555956",
#   "otherResponseBytes": "11580",
#   "numberJsResources": 49,
#   "numberCssResources": 2
#  },
#  "formattedResults": {
#   "locale": "en_US",
#   "ruleResults": {
#    "AvoidLandingPageRedirects": {
#     "localizedRuleName": "Avoid landing page redirects",
#     "ruleImpact": 0.0,
#     "urlBlocks": [
#      {
#       "header": {
#        "format": "Your page has no redirects. Learn more about avoiding landing page redirects.",
#        "args": [
# ...

# %%
desktop = json.loads(desktop.content.decode('utf8'))
mobile = json.loads(mobile.content.decode('utf8'))

# %%
for key in mobile.keys():
    print('mobile[\''+key+'\']')
# Out:
# mobile['kind']
# mobile['id']
# mobile['responseCode']
# mobile['title']
# mobile['score']
# mobile['pageStats']
# mobile['formattedResults']
# mobile['version']

# %%
mobile['kind']
# Out:
# 'pagespeedonline#result'

# %%
mobile['id']
# Out:
# 'http://www.lazada.vn/cach-mang-mua-sam-online/'

# %%
mobile['title']
# Out:
# 'Chương trình khuyến mãi Cách Mạng Mua Sắm Online tại Lazada.vn'

# %%
mobile['score']
# Out:
# 46

# %%
mobile['version']
# Out:
# {'major': 1, 'minor': 15}

# %%
mobile['pageStats']
# Out:
# {'cssResponseBytes': '512264',
#  'htmlResponseBytes': '2383016',
#  'imageResponseBytes': '872347',
#  'javascriptResponseBytes': '2282843',
#  'numberCssResources': 3,
#  'numberHosts': 37,
#  'numberJsResources': 36,
#  'numberResources': 114,
#  'numberStaticResources': 71,
#  'otherResponseBytes': '23764',
#  'textResponseBytes': '1302',
#  'totalRequestBytes': '25843'}

# %%
mobile['formattedResults']
# Out:
# {'locale': 'en_US',
#  'ruleResults': {'AvoidLandingPageRedirects': {'localizedRuleName': 'Avoid landing page redirects',
#    'ruleImpact': 0.0,
#    'urlBlocks': [{'header': {'args': [{'type': 'HYPERLINK',
#         'value': 'https://developers.google.com/speed/docs/insights/AvoidRedirects'}],
#       'format': 'Your page has no redirects. Learn more about avoiding landing page redirects.'}}]},
#   'AvoidPlugins': {'localizedRuleName': 'Avoid plugins',
#    'ruleImpact': 0.0,
#    'urlBlocks': [{'header': {'args': [{'type': 'HYPERLINK',
#         'value': 'https://developers.google.com/speed/docs/insights/AvoidPlugins'}],
#       'format': 'Your page does not appear to use plugins, which would prevent content from being usable on many platforms. Learn more about the importance of avoiding plugins.'}}]},
#   'ConfigureViewport': {'localizedRuleName': 'Configure the viewport',
#    'ruleImpact': 0.0,
#    'urlBlocks': [{'header': {'args': [{'type': 'HYPERLINK',
# ...

# %%
mobile['formattedResults'].keys()
# Out:
# dict_keys(['locale', 'ruleResults'])

# %%
mobile['formattedResults']['locale']
# Out:
# 'en_US'

# %%
frs=mobile['formattedResults']['ruleResults']
frs
# Out:
# {'AvoidLandingPageRedirects': {'localizedRuleName': 'Avoid landing page redirects',
#   'ruleImpact': 0.0,
#   'urlBlocks': [{'header': {'args': [{'type': 'HYPERLINK',
#        'value': 'https://developers.google.com/speed/docs/insights/AvoidRedirects'}],
#      'format': 'Your page has no redirects. Learn more about avoiding landing page redirects.'}}]},
#  'AvoidPlugins': {'localizedRuleName': 'Avoid plugins',
#   'ruleImpact': 0.0,
#   'urlBlocks': [{'header': {'args': [{'type': 'HYPERLINK',
#        'value': 'https://developers.google.com/speed/docs/insights/AvoidPlugins'}],
#      'format': 'Your page does not appear to use plugins, which would prevent content from being usable on many platforms. Learn more about the importance of avoiding plugins.'}}]},
#  'ConfigureViewport': {'localizedRuleName': 'Configure the viewport',
#   'ruleImpact': 0.0,
#   'urlBlocks': [{'header': {'args': [{'type': 'HYPERLINK',
# ...

# %%
def extract(header):
    formatstr = header['format']
    if 'args' in header.keys():
        args = header['args']
        for i, arg in enumerate(args):
            if args[i]['type']=='HYPERLINK':
                formatstr=formatstr+'\n'+args[i]['value']
            else:
                val = args[i]['value']
                if 'SNAPSHOT' in args[i]['type']:
                    val=''
                formatstr = formatstr.replace('$'+str(i+1), val)
    return formatstr
def split_titled_string(_str):
    for a in _str:
        if a.isupper():
            _str=_str.replace(a, ' '+a)
    return _str.strip()

def get_issues(json_dict):
    
    df=[]
    for key in json_dict['formattedResults']['ruleResults'].keys():
        data={'Device':target_device}
        data['Problem']=split_titled_string(key)
        data['Important']=round(frs[key]['ruleImpact'], 2)
        print(data['Problem'])
        #print(str(frs[key]['ruleImpact'])+'\t'+key)
        print(len(frs[key]['urlBlocks']))
        Headers=''
        Details='#\n'
        for blocks in frs[key]['urlBlocks']:
            Headers = Headers+extract(blocks['header'])+'\n'
            print('Headers')
            print(Headers)
            print(blocks.keys())
            if 'urls' in blocks.keys():
                print(blocks)
                for i in blocks['urls']:
                    Details=Details+(extract(i['result']))+'\n'
                data['Details']=Details
                print('Details')
                print(Details)
        data['Headers']=Headers

        df.append(data)
    return df

# %%
issues=DataFrame(get_issues(desktop)).sort_values(['Important'],
                                                  ascending=False).reset_index(drop=True)
issues.keys()
# Out:
# Avoid Landing Page Redirects
# 1
# Headers
# Your page has no redirects. Learn more about avoiding landing page redirects.
# https://developers.google.com/speed/docs/insights/AvoidRedirects
#
# dict_keys(['header'])
# Enable Gzip Compression
# 2
# Headers
# Compressing resources with gzip or deflate can reduce the number of bytes sent over the network.
#
# dict_keys(['header'])
# Headers
# Compressing resources with gzip or deflate can reduce the number of bytes sent over the network.
# Enable compression for the following resources to reduce their transfer size by 21.2KiB (70% reduction).
# https://developers.google.com/speed/docs/insights/EnableCompression
#
# dict_keys(['header', 'urls'])
# ...

# %%
issues.values
# Out:
# array([[ '#\nhttp://vn-live-03.slatic.net/searchpage/vendor/scripts/core_mobile/libs/modernizr-custom-4886d6f304.js\nhttp://vn-live-01.slatic.net/searchpage/js/ga-timing-09c472c8cc.js\nhttp://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js\nhttp://vn-live-01.slatic.net/searchpage/build/mobile-catalog-77ab6d963e.js\nhttps://vn-live.slatic.net/pagemanager_widgets/load-pmWidgetsWithDeps.bundle.js\nhttp://vn-live-03.slatic.net/lzdtracker/lzdtracker.js?v=2a4a781\nhttp://vn-live-01.slatic.net/lzdtracker/resource_performance.js?v=2a4a781\nhttp://vn-live-02.slatic.net/searchpage/build/mobile-main-6b929014a1.css\n',
#         'desktop',
# ...

# %%
for i, val in issues.iterrows():
# Out:
# '#\nhttp://vn-live-02.slatic.net/searchpage/build/mobile-main-6b929014a1.css\n'

# %%
get.save(issues, 
         get.dmn(target_url),
         columns=['Device', 'Problem', 'Important', 'Headers', 'Details'])

# %%
for key in frs.keys():
    #print('\nfrs[\''+key+'\']')
    for _key in frs[key].keys():
        #print('  frs[\''+key+'\'][\''+_key+'\']')
        #print(_key)
        if _key=='urlBlocks':
            header = frs[key][_key][0]['header']
            #print(header.keys())
            if 'args' in header.keys():
                _str = header['format']
                for i, arg in enumerate(header['args']):
                    _str = _str.replace('$'+str(i+1), arg['value'])
                    if arg['type']=='HYPERLINK':
                        _str = _str+'\n'+arg['value']
                #print(header['format'])
                print(_str)
            #print(str(frs[key][_key][0]))
    print('\n'+str(frs[key]))
# Out:
# Your page has no redirects. Learn more about avoiding landing page redirects.
# https://developers.google.com/speed/docs/insights/AvoidRedirects
#
# {'localizedRuleName': 'Avoid landing page redirects', 'ruleImpact': 0.0, 'urlBlocks': [{'header': {'format': 'Your page has no redirects. Learn more about avoiding landing page redirects.', 'args': [{'type': 'HYPERLINK', 'value': 'https://developers.google.com/speed/docs/insights/AvoidRedirects'}]}}]}
# Your page does not appear to use plugins, which would prevent content from being usable on many platforms. Learn more about the importance of avoiding plugins.
# https://developers.google.com/speed/docs/insights/AvoidPlugins
#
# ...

# %%
frs['LeverageBrowserCaching']['urlBlocks'][0]
# Out:
# {'header': {'format': 'Setting an expiry date or a maximum age in the HTTP headers for static resources instructs the browser to load previously downloaded resources from local disk rather than over the network.'}}

# %%
df = get.DataFrame(jrs['formattedResults']['ruleResults']).T
df = df.sort_values('ruleImpact', ascending=False)

# %%
get.save(df, 'pagespeed_api')

# %%
def run(url):
    from json import loads
    from requests import get
    from pandas import DataFrame
    api_url='https://www.googleapis.com/pagespeedonline/v1/runPagespeed'
    key='AIzaSyDGwAgFUs25FrsK6Rg_C7ketQ3K5jyo9og'
    desktop=get(api_url+'?url='+url+'&key='+key+'&strategy=desktop')
    mobile=get(api_url+'?url='+url+'&key='+key+'&strategy=mobile')
    desktop = loads(desktop.content.decode('utf8'))
    mobile = loads(mobile.content.decode('utf8'))
    def merge(data):
        formatstr = data['format']
        if 'args' in data.keys():
            args = data['args']
            for i, arg in enumerate(args):
                if args[i]['type']=='HYPERLINK':
                    formatstr=formatstr+'\n'+args[i]['value']
                else:
                    val = '' if 'SNAPSHOT' in args[i]['type'] else args[i]['value']
                    formatstr = formatstr.replace('$'+str(i+1), val)
        return formatstr
    def split_titled_string(_str):
        for a in _str:
            if a.isupper(): _str=_str.replace(a, ' '+a)
        return _str.strip()
    def get_issues(json_dict):        
        df=[]
        frs = json_dict['formattedResults']['ruleResults']
        for key in frs.keys():
            data={}
            data['Problem']=split_titled_string(key)
            data['Important']=round(frs[key]['ruleImpact'], 2)
            Headers=''
            Details=''
            for blocks in frs[key]['urlBlocks']:
                Headers = Headers+merge(blocks['header'])+'\n'
                if 'urls' in blocks.keys():
                    for i in blocks['urls']:
                        Details=Details+(merge(i['result']))+'\n'
            data['Headers']=Headers
            data['Details']=Details
            df.append(data)
        return DataFrame(df).sort_values(['Important'], ascending=False).reset_index(drop=True)
        
    return {'final_url':desktop['id'],
            'desktop_score':desktop['score'],
            'desktop_issues': get_issues(desktop),
            'mobile_score':mobile['score'],
            'mobile_issues': get_issues(mobile), }

# %%
url = 'http://www.lazada.vn/cach-mang-mua-sam-online/'
from json import loads
from requests import get
from pandas import DataFrame
api_url='https://www.googleapis.com/pagespeedonline/v1/runPagespeed'
key='AIzaSyDGwAgFUs25FrsK6Rg_C7ketQ3K5jyo9og'
desktop=get(api_url+'?url='+url+'&key='+key+'&strategy=desktop')
mobile=get(api_url+'?url='+url+'&key='+key+'&strategy=mobile')
desktop = loads(desktop.content.decode('utf8'))
mobile = loads(mobile.content.decode('utf8'))
def merge(data):
    formatstr = data['format']
    if 'args' in data.keys():
        args = data['args']
        for i, arg in enumerate(args):
            if args[i]['type']=='HYPERLINK':
                formatstr=formatstr+'\n'+args[i]['value']
            else:
                val = '' if 'SNAPSHOT' in args[i]['type'] else args[i]['value']
                formatstr = formatstr.replace('$'+str(i+1), val)
    return formatstr
def split_titled_string(_str):
    for a in _str:
        if a.isupper(): _str=_str.replace(a, ' '+a)
    return _str.strip()
def get_issues(json_dict):        
    df=[]
    frs = json_dict['formattedResults']['ruleResults']
    for key in frs.keys():
        data={}
        data['Problem']=split_titled_string(key)
        data['Important']=round(frs[key]['ruleImpact'], 2)
        Headers=''
        Details=''
        for blocks in frs[key]['urlBlocks']:
            Headers = Headers+merge(blocks['header'])+'\n'
            if 'urls' in blocks.keys():
                for i in blocks['urls']:
                    Details=Details+(merge(i['result']))+'\n'
        data['Headers']=Headers
        data['Details']=Details
        df.append(data)
    return DataFrame(df).sort_values(['Important'], ascending=False).reset_index(drop=True)

# %%
save(get_issues(desktop), 'SEOAudit_pagespeed_demo_desktop', 
         columns=['Problem', 'Important', 'Headers', 'Details'])
# Out:
# c:\users\thinkpad\appdata\local\programs\python\python36-32\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://vn-live-01.slatic.net/searchpage/vendor/scripts/modernizr/modernizr-custom-cc1027d9e8.js
# http://ajax.googleapis.com/ajax/libs/jquery/1.8.1/jquery.min.js
# http://vn-live-01.slatic.net/searchpage/js/ga-timing-09c472c8cc.js
# http://vn-live-03.slatic.net/searchpage/build/desktop-catalog-aa84617ee3.js
# http://vn-live-02.slatic.net/searchpage/build/desktop-inner-aee1d1b480.js
# http://vn-live-03.slatic.net/lzdtracker/lzdtracker.js?v=2a4a781
# http://vn-live-01.slatic.net/lzdtracker/resource_performance.js?v=2a4a781
# http://vn-live-03.slatic.net/searchpage/build/desktop-catalog-8c447ac649.css
# http://vn-live-02.slatic.net/searchpage/build/desktop-inner-fbe9ce5c80.css
# ' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# ...

# %%
save(get_issues(mobile), 'SEOAudit_pagespeed_demo_mobile', 
         columns=['Problem', 'Important', 'Headers', 'Details'])
# Out:
# c:\users\thinkpad\appdata\local\programs\python\python36-32\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://vn-live-03.slatic.net/searchpage/vendor/scripts/core_mobile/libs/modernizr-custom-4886d6f304.js
# http://vn-live-01.slatic.net/searchpage/js/ga-timing-09c472c8cc.js
# http://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js
# http://vn-live-01.slatic.net/searchpage/build/mobile-catalog-77ab6d963e.js
# https://vn-live.slatic.net/pagemanager_widgets/load-pmWidgetsWithDeps.bundle.js
# http://vn-live-03.slatic.net/lzdtracker/lzdtracker.js?v=2a4a781
# http://vn-live-01.slatic.net/lzdtracker/resource_performance.js?v=2a4a781
# http://vn-live-02.slatic.net/searchpage/build/mobile-main-6b929014a1.css
# ' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# ...
